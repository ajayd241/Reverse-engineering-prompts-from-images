# %%
import os
import unicodedata
import pandas as pd
from tqdm.notebook import tqdm

# %%
def is_english_only(string):
    for s in string:
        cat = unicodedata.category(s)         
        if not cat in ['Ll', 'Lu', 'Nd', 'Po', 'Pd', 'Zs']:
            return False
    return True

# %%
df = pd.read_parquet('./metadata.parquet', columns=['image_name', 'prompt', 'width', 'height'])
df = df[(df['width'] == 512) & (df['height'] == 512)]
df['prompt'] = df['prompt'].str.strip()
df = df[df['prompt'].map(lambda x: len(x.split())) >= 5]
df = df[~df['prompt'].str.contains('^(?:\s*|NULL|null|NaN)$', na=True)]
df = df[df['prompt'].apply(is_english_only)]
df['head'] = df['prompt'].str[:15]
df['tail'] = df['prompt'].str[-15:]
df.drop_duplicates(subset='head', inplace=True)
df.drop_duplicates(subset='tail', inplace=True)
df.reset_index(drop=True, inplace=True)

# for i in tqdm(range(1, 2000, 100)):
    # image_dir = f'/kaggle/input/diffusiondb-2m-part-{str(i).zfill(4)}-to-{str(i+99).zfill(4)}-of-2000/'
    # images = os.listdir(image_dir)
    # df.loc[df['image_name'].isin(images), 'filepath'] = image_dir + df['image_name']
    # break

image_dir = './images/'
images = os.listdir(image_dir)
df.loc[df['image_name'].isin(images), 'filepath'] = image_dir + df['image_name']
df = df[['filepath', 'prompt']].copy()
# assert not df['filepath'].isnull().any()
df
# Out:
#                                                  filepath  \
# 0       ./images/2217ccbd-a1c6-47ac-9a2d-79649727c834.png
# 1       ./images/48eb7e17-a3cf-4eb8-96a9-d8e3e23fa1af.png
# 2       ./images/2919b048-6f68-4ac7-a6d5-060d827abb77.png
# 3       ./images/3c835fdc-9047-4298-ac8a-7461f5490132.png
# 4       ./images/454d7550-a6cf-4896-befb-e2449b281265.png
# ...                                                   ...
# 154315                                                NaN
# 154316                                                NaN
# 154317                                                NaN
# 154318                                                NaN
# 154319                                                NaN
#
#                                                    prompt
# 0       a portrait of a female robot made from code, v...
# 1                         dream swimming pool with nobody
# 2       a beautiful paint of cultists dancing surround...
# 3       frontal portrait of ragged, worried twin women...
# 4       a stunning portrait of an asian samurai with l...
# ...                                                   ...
# 154315  obama transformed into a penguin, a combinatio...
# 154316             new york invaded by nazis, concept art
# 154317  a owlish, aquiline picture of an owl sitting o...
# 154318  a owlish, elaborate painting of an owl sitting...
# 154319               a rose with the face of jerry garcia
#
# [154320 rows x 2 columns]

# %%
df.dropna()
# Out:
#                                                 filepath  \
# 0      ./images/2217ccbd-a1c6-47ac-9a2d-79649727c834.png
# 1      ./images/48eb7e17-a3cf-4eb8-96a9-d8e3e23fa1af.png
# 2      ./images/2919b048-6f68-4ac7-a6d5-060d827abb77.png
# 3      ./images/3c835fdc-9047-4298-ac8a-7461f5490132.png
# 4      ./images/454d7550-a6cf-4896-befb-e2449b281265.png
# ...                                                  ...
# 13782  ./images/ed551b2a-7cd2-4211-aedc-ec41efd60e5b.png
# 13783  ./images/267752e2-402b-4b4c-8d83-76b8650bfecc.png
# 13784  ./images/5f2ba410-5a01-4ead-a521-b54e043b1ae5.png
# 13785  ./images/c2060394-6fc3-49c0-92c2-9475b6f50125.png
# 13786  ./images/6b416298-e25d-47ef-ad60-229e7961cc5b.png
#
#                                                   prompt
# 0      a portrait of a female robot made from code, v...
# 1                        dream swimming pool with nobody
# 2      a beautiful paint of cultists dancing surround...
# 3      frontal portrait of ragged, worried twin women...
# 4      a stunning portrait of an asian samurai with l...
# ...                                                  ...
# 13782                taylor swift drawn by a preschooler
# 13783                            nemo anime girl fan art
# 13784  dismal house standing in the bleak dark depres...
# 13785  a macro 3 5 mm photograph of two mice in hawai...
# 13786  foreign alien geography, crayon, pastel art, p...
#
# [13787 rows x 2 columns]

# %%
df = pd.read_parquet('metadata.parquet')

# %%
df
# Out:
#                                        image_name  \
# 0        2217ccbd-a1c6-47ac-9a2d-79649727c834.png
# 1        c78807b7-d55a-4a2d-a6b6-9192b18941ad.png
# 2        dc71658a-5e4b-4dca-861a-e1535510348b.png
# 3        48eb7e17-a3cf-4eb8-96a9-d8e3e23fa1af.png
# 4        601d9792-eccd-4850-97a7-edbe91d3464c.png
# ...                                           ...
# 1999995  4a34854e-e117-4b69-b1da-cc74534524c0.png
# 1999996  d4ae6d4f-762c-42f0-9481-a1c233e6a541.png
# 1999997  67dac228-3631-4036-8498-a40a67a7d354.png
# 1999998  9d57179b-de12-460b-a699-a66dfca528be.png
# 1999999  0ae508b1-f140-48c9-9da4-a124967215cf.png
#
#                                                     prompt  part_id  \
# 0        a portrait of a female robot made from code, v...        1
# 1        a portrait of a female robot made from a cloud...        1
# 2            only memories remain, trending on artstation         1
# 3                         dream swimming pool with nobody         1
# 4                 a dog doing weights. epic oil painting.         1
# ...                                                    ...      ...
# 1999995  david bowie giving a piggy back ride to ziggy ...     2000
# 1999996  david bowie giving a piggy back ride to ziggy ...     2000
# 1999997                                    funny computer      2000
# 1999998                 hilarious witty computing machine      2000
# 1999999   hilarious witty computing machine, lichtenstien      2000
#
#                seed  step   cfg  sampler  width  height  \
# 0        2615452544    50   7.0        8    512     512
# 1        4231506957    50   7.0        8    512     512
# 2         544607824    50   7.0        8    512     512
# 3        3500509234    50   7.0        8    512     512
# 4        1312381211    50  12.0        8    512     768
# ...             ...   ...   ...      ...    ...     ...
# 1999995  3003198679    50   7.0        8    512     512
# 1999996  3003198679    50   7.0        8    512     512
# 1999997  3602197422    50   7.0        8    512     512
# 1999998  1604720580    50   7.0        8    512     512
# 1999999  2354141979    50   7.0        8    512     512
#
#                                                  user_name  \
# 0        0167cc490c3dc6047be855b096a9b9d8f20e2b034532bd...
# 1        0167cc490c3dc6047be855b096a9b9d8f20e2b034532bd...
# 2        0167cc490c3dc6047be855b096a9b9d8f20e2b034532bd...
# 3        019084defdd44d2dfcd200bf7aaae53034263168e10d6b...
# 4        03cb377ebf364ea2761b5710625974c0d2d25285fec982...
# ...                                                    ...
# 1999995  fff4138cde262b5632a036752b40ddec8cb0a53c549123...
# 1999996  fff4138cde262b5632a036752b40ddec8cb0a53c549123...
# 1999997  fff4138cde262b5632a036752b40ddec8cb0a53c549123...
# 1999998  fff4138cde262b5632a036752b40ddec8cb0a53c549123...
# 1999999  fff4138cde262b5632a036752b40ddec8cb0a53c549123...
#
#                         timestamp  image_nsfw  prompt_nsfw
# 0       2022-08-20 11:56:00+00:00    0.554853     0.001621
# 1       2022-08-20 11:59:00+00:00    0.153645     0.000707
# 2       2022-08-20 12:02:00+00:00    0.062496     0.000425
# 3       2022-08-20 07:22:00+00:00    0.030799     0.003586
# 4       2022-08-20 12:28:00+00:00    0.181035     0.030822
# ...                           ...         ...          ...
# 1999995 2022-08-16 04:51:00+00:00    0.152736     0.022676
# 1999996 2022-08-16 04:53:00+00:00    0.127884     0.014115
# 1999997 2022-08-16 05:41:00+00:00    0.093476     0.000463
# 1999998 2022-08-16 06:47:00+00:00    0.124379     0.002547
# 1999999 2022-08-16 06:48:00+00:00    0.044811     0.000964
#
# [2000000 rows x 13 columns]

# %%
images = os.listdir('./images/')

# %%
len(images)
# Out:
# 100000

# %%
df[df['image_name'].isin(images)]
# Out:
#                                      image_name  \
# 0      2217ccbd-a1c6-47ac-9a2d-79649727c834.png
# 1      c78807b7-d55a-4a2d-a6b6-9192b18941ad.png
# 2      dc71658a-5e4b-4dca-861a-e1535510348b.png
# 3      48eb7e17-a3cf-4eb8-96a9-d8e3e23fa1af.png
# 4      601d9792-eccd-4850-97a7-edbe91d3464c.png
# ...                                         ...
# 99995  f091c225-1451-4161-80b2-e4c956c183e9.png
# 99996  425e532c-1c67-47f8-b758-58cf3fee1bb3.png
# 99997  839fcf92-1c2e-4a22-affd-7510b70b6bde.png
# 99998  09019207-7eb2-408c-a30b-c6c028e424a6.png
# 99999  2d77791c-4025-4a6d-b69b-65e49f6693ce.png
#
#                                                   prompt  part_id        seed  \
# 0      a portrait of a female robot made from code, v...        1  2615452544
# 1      a portrait of a female robot made from a cloud...        1  4231506957
# 2          only memories remain, trending on artstation         1   544607824
# 3                       dream swimming pool with nobody         1  3500509234
# 4               a dog doing weights. epic oil painting.         1  1312381211
# ...                                                  ...      ...         ...
# 99995  hyperrealistic portrait of a handsome male hea...      100  1379276895
# 99996  hyperdetailed portrait of elizabeth olsen as s...      100  4194905603
# 99997  hyperdetailed portrait of henry cavill as a ma...      100  1639252212
# 99998  hyperdetailed portrait of chris evans rugged r...      100  1488736428
# 99999  candy pizza topped with sugar sugar sugar suga...      100  3929617916
#
#        step   cfg  sampler  width  height  \
# 0        50   7.0        8    512     512
# 1        50   7.0        8    512     512
# 2        50   7.0        8    512     512
# 3        50   7.0        8    512     512
# 4        50  12.0        8    512     768
# ...     ...   ...      ...    ...     ...
# 99995    50   9.0        8    512     640
# 99996    50   9.0        8    640     512
# 99997    50   9.0        8    512     640
# 99998    50   9.0        8    512     640
# 99999    50   9.0        8    512     512
#
#                                                user_name  \
# 0      0167cc490c3dc6047be855b096a9b9d8f20e2b034532bd...
# 1      0167cc490c3dc6047be855b096a9b9d8f20e2b034532bd...
# 2      0167cc490c3dc6047be855b096a9b9d8f20e2b034532bd...
# 3      019084defdd44d2dfcd200bf7aaae53034263168e10d6b...
# 4      03cb377ebf364ea2761b5710625974c0d2d25285fec982...
# ...                                                  ...
# 99995  ffee0f4b6fd0fa325e9b53fab6f2098ff2c0414e6e0d99...
# 99996  ffee0f4b6fd0fa325e9b53fab6f2098ff2c0414e6e0d99...
# 99997  ffee0f4b6fd0fa325e9b53fab6f2098ff2c0414e6e0d99...
# 99998  ffee0f4b6fd0fa325e9b53fab6f2098ff2c0414e6e0d99...
# 99999  ffee0f4b6fd0fa325e9b53fab6f2098ff2c0414e6e0d99...
#
#                       timestamp  image_nsfw  prompt_nsfw
# 0     2022-08-20 11:56:00+00:00    0.554853     0.001621
# 1     2022-08-20 11:59:00+00:00    0.153645     0.000707
# 2     2022-08-20 12:02:00+00:00    0.062496     0.000425
# 3     2022-08-20 07:22:00+00:00    0.030799     0.003586
# 4     2022-08-20 12:28:00+00:00    0.181035     0.030822
# ...                         ...         ...          ...
# 99995 2022-08-18 06:37:00+00:00    0.229731     0.002274
# 99996 2022-08-18 06:44:00+00:00    0.080147     0.000995
# 99997 2022-08-18 06:49:00+00:00    0.111912     0.020084
# 99998 2022-08-18 06:53:00+00:00    0.639888     0.001248
# 99999 2022-08-18 06:57:00+00:00    0.036614     0.003005
#
# [100000 rows x 13 columns]
